# %%
#import mat73
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
#load = mat73.loadmat("../data/dyntest-0.mat")
load = h5py.File('../data/dyntest-0.mat','r') 
timeGSf1h = load["results"]

timeGSf1 = np.array([[load[timeGSf1h[t]][i] for t in range(101)] for i in range(67)])

# %%
#load = mat73.loadmat("../data/dyntest-0.mat")
load = h5py.File('../data/dyntest-1.mat','r') 
timeASh = load["results"]

timeAS = np.array([[load[timeASh[t]][i] for t in range(1001)] for i in range(96)])

# %%
#load = mat73.loadmat("../data/dyntest-0.mat")
load = h5py.File('../data/dyntest-2.mat','r') 
timeFh = load["results"]

timeF = np.array([[load[timeFh[t]][i] for t in range(1001)] for i in range(96)])

# %%
#load = mat73.loadmat("../data/dyntest-0.mat")
load = h5py.File('../data/dyntest-3.mat','r') 
timeGSf2h = load["results"]

timeGSf2 = np.array([[load[timeGSf2h[t]][i] for t in range(101)] for i in range(148)])

# %%
#plt.figure(figsize=(2.8, .5),constrained_layout=True)
fig, ax = plt.subplots(figsize=(2.1, .7),constrained_layout=True)
'''
for i in range(67):
    plt.plot(range(131),np.concatenate((np.ones(30), timeGSf1[i])))
'''
for i in range(20):
    ax.plot(range(121),np.concatenate((np.ones(20), timeGSf1[i])),alpha=0.5) # 1, 3, 7
ax.set_ylim(0,1.6)
ax.set_xlim(0,100)
ax.set_xticks([])
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.savefig('../figures/GS1.png', dpi = 300)

# %%
#plt.figure(figsize=(2.8, .5),constrained_layout=True)
fig, ax = plt.subplots(figsize=(2.1, .7),constrained_layout=True)
'''
for i in range(67):
    plt.plot(range(131),np.concatenate((np.ones(30), timeGSf1[i]))) [0,1,2,6,9,10,11,12,13,14]
'''
for i in range(48):
    ax.plot(range(1251),np.concatenate((np.ones(250), timeAS[i])),alpha=0.3) # 1, 3, 7

for i in [6]:
    ax.plot(range(1251),np.concatenate((np.ones(250), timeF[i])),color='k')

ax.set_ylim(0,3.5)
ax.set_xlim(0,1251)
ax.set_xticks([])
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.savefig('../figures/ASGSp.png', dpi = 300)

# %%
#plt.figure(figsize=(2.8, .5),constrained_layout=True)
fig, ax = plt.subplots(figsize=(2.1, .7),constrained_layout=True)
'''
for i in range(67):
    plt.plot(range(131),np.concatenate((np.ones(30), timeGSf1[i]))) [0,1,2,6,9,10,11,12]
'''
for i in range(48):
    ax.plot(range(1251),np.concatenate((np.ones(250), timeF[i])),alpha=0.3) # 1, 3, 7

for i in [6]:
    ax.plot(range(1251),np.concatenate((np.ones(250), timeF[i])),color='k') # 1, 3, 7

ax.set_ylim(0,3)
ax.set_xlim(0,1251)
ax.set_xticks([])
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.savefig('../figures/Fluc.png', dpi = 300)

# %%
#plt.figure(figsize=(2.8, .5),constrained_layout=True)
fig, ax = plt.subplots(figsize=(2.1, .7),constrained_layout=True)

for i in range(100):
    ax.plot(range(121),np.concatenate((np.ones(20), timeGSf2[i])),alpha=0.5) # 1, 3, 7

ax.set_ylim(0,1.8)
ax.set_xlim(0,100)
ax.set_xticks([])
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.savefig('../figures/GS2.png', dpi = 300)
